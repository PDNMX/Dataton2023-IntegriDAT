# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import datetime
from dateutil.parser import parse
import gc

# %%
#all_files_s1 = glob.glob(os.path.join("s1" , "*/*.json"))
#s1_df_from_each_file = (pd.read_json(f) for f in all_files_s1)
#s1_df = pd.concat(s1_df_from_each_file, ignore_index=True)
#s1_df.to_pickle("s1_df_raw.pkl")
s1_df = pd.read_pickle("s1_df_raw.pkl")

# %%
s1_df = s1_df[["declaracion"]]

# %%
declaracion = pd.json_normalize(s1_df.declaracion)

# %%
del s1_df

# %%
gc.collect()
# Out:
# 7

# %%
declaracion.to_pickle("s1_declaracion.pkl")

# %%
declaracion
# Out:
#         situacionPatrimonial.datosGenerales.nombre  \
# 0                                           ADRIAN
# 1                                   ABIGAIN YARELI
# 2                                           ADELFO
# 3                                    ADRIAN EMILIO
# 4                                             ABEL
# ...                                            ...
# 1354292                              ZULEMA LINETH
# 1354293                              ZULEMA LINETH
# 1354294                             ZULMA VERONICA
# 1354295                             ZULMA VERONICA
# 1354296                             ZULMA VERONICA
#
#         situacionPatrimonial.datosGenerales.primerApellido  \
# 0                                                HERNANDEZ
# 1                                                HERNANDEZ
# 2                                                HERNANDEZ
# 3                                                 MADRIGAL
# 4                                                    LEMUS
# ...                                                    ...
# 1354292                                          HERNANDEZ
# 1354293                                          HERNANDEZ
# 1354294                                              CASAS
# 1354295                                              CASAS
# 1354296                                              CASAS
#
#         situacionPatrimonial.datosGenerales.segundoApellido  \
# 0                                                HERNANDEZ
# 1                                                     CRUZ
# 2                                                    NIETO
# 3                                                 GONZALEZ
# 4                                                   TORRES
# ...                                                    ...
# 1354292                                            SANCHEZ
# 1354293                                            SANCHEZ
# 1354294                                             CHAVEZ
# 1354295                                             CHAVEZ
# 1354296                                             CHAVEZ
#
#         situacionPatrimonial.datosGenerales.correoElectronico.institucional  \
# 0                         leslieolvera.contauaeh@gmail.com
# 1                                      abilu1909@gmail.com
# 2                                     plutarco@hotmail.com
# 3
# 4
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.datosCurricularesDeclarante.escolaridad  \
# 0        [{'tipoOperacion': 'AGREGAR', 'nivel': {'clave...
# 1        [{'tipoOperacion': 'AGREGAR', 'nivel': {'clave...
# 2        [{'tipoOperacion': 'AGREGAR', 'nivel': {'clave...
# 3        [{'tipoOperacion': 'AGREGAR', 'nivel': {'clave...
# 4        [{'tipoOperacion': 'AGREGAR', 'nivel': {'clave...
# ...                                                    ...
# 1354292  [{'estatus': 'FINALIZADO', 'documentoObtenido'...
# 1354293  [{'estatus': 'FINALIZADO', 'documentoObtenido'...
# 1354294  [{'estatus': 'FINALIZADO', 'documentoObtenido'...
# 1354295  [{'estatus': 'FINALIZADO', 'documentoObtenido'...
# 1354296  [{'estatus': 'FINALIZADO', 'documentoObtenido'...
#
#         situacionPatrimonial.datosEmpleoCargoComision.tipoOperacion  \
# 0                                                  AGREGAR
# 1                                                  AGREGAR
# 2                                                  AGREGAR
# 3                                                  AGREGAR
# 4                                                  AGREGAR
# ...                                                    ...
# 1354292                                        SIN_CAMBIOS
# 1354293                                        SIN_CAMBIOS
# 1354294                                            AGREGAR
# 1354295                                            AGREGAR
# 1354296                                            AGREGAR
#
#         situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno  \
# 0                                                  ESTATAL
# 1                                                  ESTATAL
# 2                                                  ESTATAL
# 3                                                  ESTATAL
# 4                                                  ESTATAL
# ...                                                    ...
# 1354292                                            ESTATAL
# 1354293                                            ESTATAL
# 1354294                                            ESTATAL
# 1354295                                            ESTATAL
# 1354296                                            ESTATAL
#
#         situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico  \
# 0                                                EJECUTIVO
# 1                                                EJECUTIVO
# 2                                                EJECUTIVO
# 3                                                EJECUTIVO
# 4                                                EJECUTIVO
# ...                                                    ...
# 1354292                                           JUDICIAL
# 1354293                                           JUDICIAL
# 1354294                                           JUDICIAL
# 1354295                                           JUDICIAL
# 1354296                                           JUDICIAL
#
#         situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico  \
# 0                                      Contraloría General
# 1                                      Contraloría General
# 2                                      Contraloría General
# 3                                      Contraloría General
# 4                                      Contraloría General
# ...                                                    ...
# 1354292             PODER JUDICIAL DEL ESTADO DE ZACATECAS
# 1354293             PODER JUDICIAL DEL ESTADO DE ZACATECAS
# 1354294             PODER JUDICIAL DEL ESTADO DE ZACATECAS
# 1354295             PODER JUDICIAL DEL ESTADO DE ZACATECAS
# 1354296             PODER JUDICIAL DEL ESTADO DE ZACATECAS
#
#         situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion  ...  \
# 0                  3/ER. BATALLON DE INGENIEROS DE COMBATE             ...
# 1                           13 BATALLON DE POLICIA MILITAR             ...
# 2                                   ASISTENTE DE SERVICIOS             ...
# 3                                                   21 RCM             ...
# 4                                     CENTRO PENITENCIARIO             ...
# ...                                                    ...             ...
# 1354292                          ÓRGANO INTERNO DE CONTROL             ...
# 1354293                          ÓRGANO INTERNO DE CONTROL             ...
# 1354294                      DIRECCIÓN DE RECURSOS HUMANOS             ...
# 1354295                      DIRECCIÓN DE RECURSOS HUMANOS             ...
# 1354296                      DIRECCIÓN DE RECURSOS HUMANOS             ...
#
#         situacionPatrimonial.ingresos.otrosIngresosAnualesTotal  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.remuneracionConclusionCargoPublico  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.ingresoConclusionNetoDeclarante  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.totalIngresosConclusionNetos  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.ingresoConclusionNetoParejaDependiente  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.remuneracionMensualCargoPublico  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.otrosIngresosMensualesTotal  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.ingresoMensualNetoParejaDependiente  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
#         situacionPatrimonial.ingresos.totalIngresosMensualesNetos
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1354292                                                NaN
# 1354293                                                NaN
# 1354294                                                NaN
# 1354295                                                NaN
# 1354296                                                NaN
#
# [1354297 rows x 376 columns]
