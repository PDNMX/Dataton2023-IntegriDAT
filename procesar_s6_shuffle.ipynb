# %%
import findspark
findspark.init()
import pyspark
findspark.find()
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
conf = pyspark.SparkConf().setAppName('appName').setMaster('local')
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession(sc)

# %%
sc.uiWebUrl
# Out:
# 'http://host.docker.internal:4041'

# %%
s6_df = spark.read.option("recursiveFileLookup", "true").json("bulk-s6", multiLine=True)
s6_df = s6_df.repartition(10)

# %%
s6_df.printSchema()
# Out:
# root
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- awards: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- amendment: struct (nullable = true)
#  |    |    |    |-- amendsReleaseID: string (nullable = true)
#  |    |    |    |-- changes: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- date: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- rationale: string (nullable = true)
#  |    |    |    |-- releaseID: string (nullable = true)
#  |    |    |-- amendments: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- contractPeriod: struct (nullable = true)
#  |    |    |    |-- durationInDays: string (nullable = true)
#  |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |-- maxExtentDate: string (nullable = true)
#  |    |    |    |-- startDate: string (nullable = true)
#  |    |    |-- date: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- documents: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |    |-- datePublished: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- documentType: string (nullable = true)
#  |    |    |    |    |-- format: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- items: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- classification: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- quantity: double (nullable = true)
#  |    |    |    |    |-- unit: struct (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |-- rationale: string (nullable = true)
#  |    |    |-- status: string (nullable = true)
#  |    |    |-- suppliers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- additionalIdentifiers: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- address: struct (nullable = true)
#  |    |    |    |    |    |-- countryName: string (nullable = true)
#  |    |    |    |    |    |-- locality: string (nullable = true)
#  |    |    |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |    |    |-- region: string (nullable = true)
#  |    |    |    |    |    |-- streetAddress: string (nullable = true)
#  |    |    |    |    |-- contactPoint: struct (nullable = true)
#  |    |    |    |    |    |-- email: string (nullable = true)
#  |    |    |    |    |    |-- faxNumber: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- telephone: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- legalName: string (nullable = true)
#  |    |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- value: struct (nullable = true)
#  |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |-- netAmount: double (nullable = true)
#  |-- buyer: struct (nullable = true)
#  |    |-- additionalIdentifiers: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- address: struct (nullable = true)
#  |    |    |-- countryName: string (nullable = true)
#  |    |    |-- locality: string (nullable = true)
#  |    |    |-- postalCode: string (nullable = true)
#  |    |    |-- region: string (nullable = true)
#  |    |    |-- streetAddress: string (nullable = true)
#  |    |-- contactPoint: struct (nullable = true)
#  |    |    |-- email: string (nullable = true)
#  |    |    |-- faxNumber: string (nullable = true)
#  |    |    |-- givenName: string (nullable = true)
#  |    |    |-- matronymicName: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- patronymicName: string (nullable = true)
#  |    |    |-- telephone: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- identifier: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- legalName: string (nullable = true)
#  |    |    |-- legalPersonality: string (nullable = true)
#  |    |    |-- scheme: string (nullable = true)
#  |    |    |-- uri: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- position: string (nullable = true)
#  |    |-- roles: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- contracts: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- amendment: struct (nullable = true)
#  |    |    |    |-- amendsReleaseID: string (nullable = true)
#  |    |    |    |-- changes: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- date: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- rationale: string (nullable = true)
#  |    |    |    |-- releaseID: string (nullable = true)
#  |    |    |-- amendments: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- date: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- rationale: string (nullable = true)
#  |    |    |-- awardID: string (nullable = true)
#  |    |    |-- dateSigned: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- documents: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |    |-- datePublished: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- documentType: string (nullable = true)
#  |    |    |    |    |-- format: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- frameworkAgreementRequisitionNumber: string (nullable = true)
#  |    |    |-- guarantees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- date: string (nullable = true)
#  |    |    |    |    |-- guarantor: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- obligations: string (nullable = true)
#  |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |    |    |-- startDate: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- implementation: struct (nullable = true)
#  |    |    |    |-- documents: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |    |    |-- datePublished: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- documentType: string (nullable = true)
#  |    |    |    |    |    |-- format: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- milestones: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- transactions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- date: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- payee: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- payer: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- paymentMethod: string (nullable = true)
#  |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |-- netAmount: double (nullable = true)
#  |    |    |-- items: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- additionalClassifications: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- classification: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |    |    |-- deliveryAddress: struct (nullable = true)
#  |    |    |    |    |    |-- countryName: string (nullable = true)
#  |    |    |    |    |    |-- locality: string (nullable = true)
#  |    |    |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |    |    |-- region: string (nullable = true)
#  |    |    |    |    |    |-- streetAddress: string (nullable = true)
#  |    |    |    |    |-- deliveryLocation: struct (nullable = true)
#  |    |    |    |    |    |-- geometry: struct (nullable = true)
#  |    |    |    |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- quantity: long (nullable = true)
#  |    |    |    |    |-- unit: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |-- netAmount: double (nullable = true)
#  |    |    |-- milestones: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- durationInDays: string (nullable = true)
#  |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |-- maxExtentDate: string (nullable = true)
#  |    |    |    |-- startDate: string (nullable = true)
#  |    |    |-- relatedProcesses: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- identifier: string (nullable = true)
#  |    |    |    |    |-- relationship: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |-- status: string (nullable = true)
#  |    |    |-- surveillanceMechanisms: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- value: struct (nullable = true)
#  |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |-- exchangeRates: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |-- netAmount: double (nullable = true)
#  |-- cycle: long (nullable = true)
#  |-- date: string (nullable = true)
#  |-- dependencia: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- implementation: struct (nullable = true)
#  |    |-- transactions: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- payee: struct (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- payer: struct (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |-- amount: long (nullable = true)
#  |    |    |    |    |-- currency: string (nullable = true)
#  |-- initiationType: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- metadata: struct (nullable = true)
#  |    |-- actualizacion: string (nullable = true)
#  |    |-- contacto: string (nullable = true)
#  |    |-- institucion: string (nullable = true)
#  |    |-- personaContacto: string (nullable = true)
#  |-- metadatos: struct (nullable = true)
#  |    |-- fecha_despublicacion: string (nullable = true)
#  |    |-- fecha_modificacion: string (nullable = true)
#  |    |-- fecha_publicacion: string (nullable = true)
#  |    |-- fecha_registro: string (nullable = true)
#  |    |-- usuario_despublicacion: string (nullable = true)
#  |    |-- usuario_modificacion: string (nullable = true)
#  |    |-- usuario_publicacion: string (nullable = true)
#  |    |-- usuario_registro: string (nullable = true)
#  |-- ocid: string (nullable = true)
#  |-- parties: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- additionalIdentifiers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- legalName: string (nullable = true)
#  |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |-- address: struct (nullable = true)
#  |    |    |    |-- countryName: string (nullable = true)
#  |    |    |    |-- locality: string (nullable = true)
#  |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |-- region: string (nullable = true)
#  |    |    |    |-- streetAddress: string (nullable = true)
#  |    |    |-- contactPoint: struct (nullable = true)
#  |    |    |    |-- email: string (nullable = true)
#  |    |    |    |-- faxNumber: string (nullable = true)
#  |    |    |    |-- faxNumer: string (nullable = true)
#  |    |    |    |-- givenName: string (nullable = true)
#  |    |    |    |-- matronymicName: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- patronymicName: string (nullable = true)
#  |    |    |    |-- telephone: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- details: struct (nullable = true)
#  |    |    |    |-- scale: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |-- givenName: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- legalName: string (nullable = true)
#  |    |    |    |-- legalPersonality: string (nullable = true)
#  |    |    |    |-- matronymicName: string (nullable = true)
#  |    |    |    |-- patronymicName: string (nullable = true)
#  |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |-- uri: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- position: string (nullable = true)
#  |    |    |-- roles: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- planning: struct (nullable = true)
#  |    |-- budget: struct (nullable = true)
#  |    |    |-- amount: struct (nullable = true)
#  |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |-- currency: string (nullable = true)
#  |    |    |-- budgetBreakdown: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |-- amount: long (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- fundType: string (nullable = true)
#  |    |    |    |    |-- origin: string (nullable = true)
#  |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |    |    |-- startDate: string (nullable = true)
#  |    |    |    |    |-- sourceParty: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- project: string (nullable = true)
#  |    |    |-- projectID: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- uri: string (nullable = true)
#  |    |-- contractingUnits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |-- documents: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |-- datePublished: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- documentType: string (nullable = true)
#  |    |    |    |-- format: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- language: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- hasQuotes: boolean (nullable = true)
#  |    |-- milestones: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- dateMet: string (nullable = true)
#  |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- dueDate: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- rationale: string (nullable = true)
#  |    |-- requestingUnits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |-- requestsForQuotes: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- invitedSuppliers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- classification: struct (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- quantity: long (nullable = true)
#  |    |    |    |    |    |-- unit: struct (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |    |-- startDate: string (nullable = true)
#  |    |    |    |-- quotes: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- date: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- issuingSupplier: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- classification: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- unit: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |    |    |    |-- startDate: string (nullable = true)
#  |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |-- responsibleUnits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |-- publicar: string (nullable = true)
#  |-- publisher: struct (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- scheme: string (nullable = true)
#  |    |-- uid: string (nullable = true)
#  |    |-- uri: string (nullable = true)
#  |-- tag: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- tender: struct (nullable = true)
#  |    |-- additionalProcurementCategories: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- amendment: struct (nullable = true)
#  |    |    |-- amendsReleaseID: string (nullable = true)
#  |    |    |-- changes: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- date: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- rationale: string (nullable = true)
#  |    |    |-- releaseID: string (nullable = true)
#  |    |-- amendments: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- awardCriteria: string (nullable = true)
#  |    |-- awardCriteriaDetails: string (nullable = true)
#  |    |-- awardPeriod: struct (nullable = true)
#  |    |    |-- durationInDays: string (nullable = true)
#  |    |    |-- endDate: string (nullable = true)
#  |    |    |-- maxExtentDate: string (nullable = true)
#  |    |    |-- startDate: string (nullable = true)
#  |    |-- contractPeriod: struct (nullable = true)
#  |    |    |-- durationInDays: string (nullable = true)
#  |    |    |-- endDate: string (nullable = true)
#  |    |    |-- maxExtentDate: string (nullable = true)
#  |    |    |-- startDate: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- documents: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |-- datePublished: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- documentType: string (nullable = true)
#  |    |    |    |-- format: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- language: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- eligibilityCriteria: string (nullable = true)
#  |    |-- enquiryPeriod: struct (nullable = true)
#  |    |    |-- durationInDays: string (nullable = true)
#  |    |    |-- endDate: string (nullable = true)
#  |    |    |-- maxExtentDate: string (nullable = true)
#  |    |    |-- startDate: string (nullable = true)
#  |    |-- frameworkAgreement: boolean (nullable = true)
#  |    |-- frameworkAgreementPlatform: string (nullable = true)
#  |    |-- frameworkAgreementTitle: string (nullable = true)
#  |    |-- hasEnquiries: boolean (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- invitedSuppliers: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |-- items: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- additionalClassifications: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- classification: struct (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |    |-- deliveryAddress: struct (nullable = true)
#  |    |    |    |    |-- countryName: string (nullable = true)
#  |    |    |    |    |-- locality: string (nullable = true)
#  |    |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |    |-- region: string (nullable = true)
#  |    |    |    |    |-- streetAddress: string (nullable = true)
#  |    |    |    |-- deliveryLocation: struct (nullable = true)
#  |    |    |    |    |-- geometry: struct (nullable = true)
#  |    |    |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- quantity: double (nullable = true)
#  |    |    |    |-- unit: struct (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |-- uri: string (nullable = true)
#  |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- netAmount: double (nullable = true)
#  |    |-- mainProcurementCategory: string (nullable = true)
#  |    |-- milestones: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- dateMet: string (nullable = true)
#  |    |    |    |-- dateModified: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- dueDate: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- minValue: struct (nullable = true)
#  |    |    |-- amount: string (nullable = true)
#  |    |    |-- currency: string (nullable = true)
#  |    |-- numberOfTenderers: long (nullable = true)
#  |    |-- procurementMethod: string (nullable = true)
#  |    |-- procurementMethodDetails: string (nullable = true)
#  |    |-- procurementMethodRationale: string (nullable = true)
#  |    |-- procuringEntity: struct (nullable = true)
#  |    |    |-- additionalIdentifiers: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- address: struct (nullable = true)
#  |    |    |    |-- countryName: string (nullable = true)
#  |    |    |    |-- locality: string (nullable = true)
#  |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |-- region: string (nullable = true)
#  |    |    |    |-- streetAddress: string (nullable = true)
#  |    |    |-- contactPoint: struct (nullable = true)
#  |    |    |    |-- email: string (nullable = true)
#  |    |    |    |-- faxNumber: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- telephone: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- legalName: string (nullable = true)
#  |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |-- uri: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |    |-- submissionMethod: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- submissionMethodDetails: string (nullable = true)
#  |    |-- tenderPeriod: struct (nullable = true)
#  |    |    |-- durationInDays: string (nullable = true)
#  |    |    |-- endDate: string (nullable = true)
#  |    |    |-- maxExtentDate: string (nullable = true)
#  |    |    |-- startDate: string (nullable = true)
#  |    |-- tenderers: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- amount: double (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- value: struct (nullable = true)
#  |    |    |-- amount: string (nullable = true)
#  |    |    |-- currency: string (nullable = true)

# %%
s6_df = s6_df.withColumn("explode_awards", explode_outer("awards")) \
.withColumn("explode_parties", explode_outer("parties"))

# %%
new_cols_select_contract = ", ".join(["explode_awards.contractPeriod." + col + " as contractPeriod_" + col for col in s6_df.select("explode_awards.contractPeriod.*").columns])
new_cols_select_parties = ", ".join(["explode_parties." + col + " as parties_" + col for col in s6_df.select("explode_parties.*").columns])
s6_df.createOrReplaceTempView("s6_df")

# %%
new_cols_select_contract
# Out:
# 'explode_awards.contractPeriod.durationInDays as contractPeriod_durationInDays, explode_awards.contractPeriod.endDate as contractPeriod_endDate, explode_awards.contractPeriod.maxExtentDate as contractPeriod_maxExtentDate, explode_awards.contractPeriod.startDate as contractPeriod_startDate'

# %%
s6_df = spark.sql("select ocid, id, _id, " + new_cols_select_contract + ", " + new_cols_select_parties + " from s6_df")

# %%
schema = ("ocid", "id", col("_id.$oid").alias("_id.$oid"), "contractPeriod_durationInDays", "contractPeriod_endDate", "contractPeriod_maxExtentDate", "contractPeriod_startDate",
          "parties_name", col("parties_contactPoint.name").alias("parties_contactPoint_name"))

# %%
s6_df = s6_df.select(*schema)

# %%
s6_df.printSchema()
# Out:
# root
#  |-- ocid: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- _id.$oid: string (nullable = true)
#  |-- contractPeriod_durationInDays: string (nullable = true)
#  |-- contractPeriod_endDate: string (nullable = true)
#  |-- contractPeriod_maxExtentDate: string (nullable = true)
#  |-- contractPeriod_startDate: string (nullable = true)
#  |-- parties_name: string (nullable = true)
#  |-- parties_contactPoint_name: string (nullable = true)

# %%
s6_df.write.parquet("s6_extracted_repartition")
