# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import datetime
from dateutil.parser import parse
import gc
from tqdm import tqdm
tqdm.pandas()

# %%
s6_df = pd.read_hdf("s6_hdf.h5")

# %%
def parse_date(x):
    try:
        return parse(x)
    except:
        return None
    
def find_earliest_date(dates):
    try:
        if len(dates) > 0:
            dates = [parse_date(date) for date in dates]
            dates = [x for x in dates if x is not None]
            if len(dates) > 0:
                earliest = min(dates)
            else:
                earliest = None
        else:
            earliest = None
        return earliest
    except:
        return None
    
            
def find_latest_date(dates):
    try:
        if len(dates) > 0:
            dates = [parse_date(date) for date in dates]
            dates = [x for x in dates if x is not None]
            if len(dates) > 0:
                latest = max(dates)
            else:
                latest = None
        else:
            latest = None
        return latest
    except:
        return None

# %%
s6_df.head()
# Out:
#                    _id.$oid                             ocid  id  \
# 0  62a913e7db2a665c4fce6223  ocds-ty10ed-03-06-2022-10:13:43  11
# 1  62a913e7db2a665c4fce6223  ocds-ty10ed-03-06-2022-10:13:43  11
# 2  62a913e7db2a665c4fce6226  ocds-ty10ed-07-06-2022-10:37:52  14
# 3  62a913e7db2a665c4fce6226  ocds-ty10ed-07-06-2022-10:37:52  14
# 4  62a913e7db2a665c4fce6225  ocds-ty10ed-06-06-2022-08:06:10  13
#
#   contractPeriod_startDate  contractPeriod_endDate  \
# 0   [2022-06-14T11:21:02Z]  [2022-06-14T11:21:02Z]
# 1   [2022-06-14T11:21:02Z]  [2022-06-14T11:21:02Z]
# 2   [2022-06-14T11:21:02Z]  [2022-06-14T11:21:02Z]
# 3   [2022-06-14T11:21:02Z]  [2022-06-14T11:21:02Z]
# 4   [2022-06-14T11:21:02Z]  [2022-06-14T11:21:02Z]
#
#                      parties_name  \
# 0            SESEA AGUASCALIENTES
# 1             Nissan Torres Corzo
# 2            SESEA AGUASCALIENTES
# 3  Grant Limpieza y mantenimiento
# 4            SESEA AGUASCALIENTES
#
#                            parties_contactPoint_name
# 0                   Monica Lizbeth de la Cruz Ortega
# 1  Grupo Torres Corzo Automotriz de Aguascaliente...
# 2                   Monica Lizbeth de la Cruz Ortega
# 3                     Grant Limpieza y mantenimiento
# 4                   Monica Lizbeth de la Cruz Ortega

# %%
s6_df["earliest_contractPeriod_startDate"] = s6_df.contractPeriod_startDate.progress_apply(find_earliest_date)
s6_df["latest_contractPeriod_endDate"] = s6_df.contractPeriod_endDate.progress_apply(find_latest_date)
# Out:
#   0%|          | 0/4077798 [00:00<?, ?it/s]
# 100%|██████████| 4077798/4077798 [13:34<00:00, 5006.26it/s]
# 100%|██████████| 4077798/4077798 [13:35<00:00, 5001.17it/s]

# %%
s6_df = s6_df.drop(columns=["contractPeriod_startDate", "contractPeriod_endDate"])

# %%
s6_df['earliest_contractPeriod_startDate'] = s6_df['earliest_contractPeriod_startDate'].progress_apply(lambda x: pd.to_datetime(x, utc=True))
s6_df['latest_contractPeriod_endDate'] = s6_df['latest_contractPeriod_endDate'].progress_apply(lambda x: pd.to_datetime(x, utc=True))

s6_df['earliest_contractPeriod_startDate'] = s6_df['earliest_contractPeriod_startDate'].dt.date
s6_df['latest_contractPeriod_endDate'] = s6_df['latest_contractPeriod_endDate'].dt.date

# %%
s6_df
# Out:
#                          _id.$oid                             ocid  \
# 0        62a913e7db2a665c4fce6223  ocds-ty10ed-03-06-2022-10:13:43
# 1        62a913e7db2a665c4fce6223  ocds-ty10ed-03-06-2022-10:13:43
# 2        62a913e7db2a665c4fce6226  ocds-ty10ed-07-06-2022-10:37:52
# 3        62a913e7db2a665c4fce6226  ocds-ty10ed-07-06-2022-10:37:52
# 4        62a913e7db2a665c4fce6225  ocds-ty10ed-06-06-2022-08:06:10
# ...                           ...                              ...
# 4077793  650873de6726d47394a0b0ca     ocds-j3etk6-LS-IVAI-004-2021
# 4077794  650873de6726d47394a0b0ca     ocds-j3etk6-LS-IVAI-004-2021
# 4077795  650873de6726d47394a0b0ca     ocds-j3etk6-LS-IVAI-004-2021
# 4077796  650873de6726d47394a0b0ca     ocds-j3etk6-LS-IVAI-004-2021
# 4077797  650873de6726d47394a0b0ca     ocds-j3etk6-LS-IVAI-004-2021
#
#                                                        id  \
# 0                                                      11
# 1                                                      11
# 2                                                      14
# 3                                                      14
# 4                                                      13
# ...                                                   ...
# 4077793  ocds-j3etk6-LS-IVAI-004-2021.v721.implementation
# 4077794  ocds-j3etk6-LS-IVAI-004-2021.v721.implementation
# 4077795  ocds-j3etk6-LS-IVAI-004-2021.v721.implementation
# 4077796  ocds-j3etk6-LS-IVAI-004-2021.v721.implementation
# 4077797  ocds-j3etk6-LS-IVAI-004-2021.v721.implementation
#
#                                          parties_name  \
# 0                                SESEA AGUASCALIENTES
# 1                                 Nissan Torres Corzo
# 2                                SESEA AGUASCALIENTES
# 3                      Grant Limpieza y mantenimiento
# 4                                SESEA AGUASCALIENTES
# ...                                               ...
# 4077793                                          OFIX
# 4077794                          TREVIÑO COMPUTACIÓN
# 4077795  EQUIPOS DE OFICINA DE VERACRUZ S.A. DE C.V.
# 4077796                                 TOTAL COPIERS
# 4077797                                     TECNOCLUB
#
#                                  parties_contactPoint_name  \
# 0                         Monica Lizbeth de la Cruz Ortega
# 1        Grupo Torres Corzo Automotriz de Aguascaliente...
# 2                         Monica Lizbeth de la Cruz Ortega
# 3                           Grant Limpieza y mantenimiento
# 4                         Monica Lizbeth de la Cruz Ortega
# ...                                                    ...
# 4077793                             ARMANDO AGUIRRE VALDÉS
# 4077794                    GRACIELA AMANDA GARCIA  TREVIÑO
# 4077795                                 EDGAR  RUIZ  LÓPEZ
# 4077796                       TIRZO ANTONIO TRONCO MORALES
# 4077797                    WILLIAM JUNUET RENDON GUTIERREZ
#
#         earliest_contractPeriod_startDate latest_contractPeriod_endDate
# 0                              2022-06-14                    2022-06-14
# 1                              2022-06-14                    2022-06-14
# 2                              2022-06-14                    2022-06-14
# 3                              2022-06-14                    2022-06-14
# 4                              2022-06-14                    2022-06-14
# ...                                   ...                           ...
# 4077793                        2021-07-09                    2021-08-25
# 4077794                        2021-07-09                    2021-08-25
# 4077795                        2021-07-09                    2021-08-25
# 4077796                        2021-07-09                    2021-08-25
# 4077797                        2021-07-09                    2021-08-25
#
# [4077798 rows x 7 columns]

# %%
s6_df.to_hdf("s6_hdf_dates.h5", key = "s6_df")
# Out:
# C:\Users\garci\AppData\Local\Temp\ipykernel_7724\1832308674.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block0_values] [items->Index(['_id.$oid', 'ocid', 'id', 'parties_name', 'parties_contactPoint_name',
#        'earliest_contractPeriod_startDate', 'latest_contractPeriod_endDate'],
#       dtype='object')]
#
#   s6_df.to_hdf("s6_hdf_dates.h5", key = "s6_df")
